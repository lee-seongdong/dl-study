# %%
import torch
# if torch.cuda.is_available():
#     print('use CUDA')
#     torch.cuda.device(0)

print("# 텐서 생성")
print(torch.tensor([[1, 2], [3, 4]])) # 2차원 텐서 생성
print(torch.tensor([[1, 2], [3, 4]], device='cuda:0')) # GPU 사용
print(torch.tensor([[1, 2], [3, 4]], dtype=torch.float64)) # 데이터 타입 지정
# Out:
# # 텐서 생성
# tensor([[1, 2],
#         [3, 4]])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 print("# 텐서 생성")
#       7 print(torch.tensor([[1, 2], [3, 4]])) # 2차원 텐서 생성
# ----> 8 print(torch.tensor([[1, 2], [3, 4]], device='cuda:0')) # GPU 사용
#       9 print(torch.tensor([[1, 2], [3, 4]], dtype=torch.float64)) # 데이터 타입 지정
#
# File c:\dev\projects\dl-study\.venv\Lib\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
print("# 텐서 변환")
temp = torch.tensor([[1, 2], [3, 4]])
print(temp.numpy()) # ndarray로 변환
temp = torch.tensor([[1, 2], [3, 4]], device='cuda:0')
print(temp.to('cpu').numpy()) # device 변환 후 ndarray로 변환

temp = torch.FloatTensor([1, 2, 3, 4, 5, 6, 7]) # 1차원 벡터 생성
print(temp)
print(temp[0], temp[1], temp[-1]) # 인덱스로 접근
print(temp[2:5], temp[4:-1]) # 슬라이스로 접근

# %%
print("# 텐서 연산")
v = torch.tensor([1, 2, 3])
w = torch.tensor([3, 4, 6])
print(w - v)

# %%
print("# 텐서 차원 변환")
temp = torch.tensor([[1, 2], [3, 4]])
print(temp.shape)
print(temp.view(4, 1)) # 2x2 -> 4x1
print(temp.view(-1)) # 2x2 -> 4
print(temp.view(1, -1)) # 2x2 -> 1x? -> 1x4
print(temp.view(-1, 1)) # 2x2 -> ?x1 -> 4x1
